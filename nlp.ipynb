# %%
import pandas as pd

# %%
pip install nltk
# Out:
# Collecting nltkNote: you may need to restart the kernel to use updated packages.
#
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Requirement already satisfied: click in c:\users\spoorthi\anaconda3\envs\tensorflow\lib\site-packages (from nltk) (8.0.4)
# Collecting tqdm
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      --------------------------------------- 78.5/78.5 kB 99.3 kB/s eta 0:00:00
# Requirement already satisfied: joblib in c:\users\spoorthi\anaconda3\envs\tensorflow\lib\site-packages (from nltk) (1.3.2)
# Collecting regex>=2021.8.3
#   Downloading regex-2024.4.16-cp37-cp37m-win_amd64.whl (269 kB)
#      ------------------------------------- 269.6/269.6 kB 69.5 kB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\spoorthi\anaconda3\envs\tensorflow\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: importlib-metadata in c:\users\spoorthi\anaconda3\envs\tensorflow\lib\site-packages (from click->nltk) (4.11.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\spoorthi\anaconda3\envs\tensorflow\lib\site-packages (from importlib-metadata->click->nltk) (4.7.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\spoorthi\anaconda3\envs\tensorflow\lib\site-packages (from importlib-metadata->click->nltk) (3.11.0)
# Installing collected packages: tqdm, regex, nltk
# Successfully installed nltk-3.8.1 regex-2024.4.16 tqdm-4.67.1

# %%
# Importing necessary libraries
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import pandas as pd
import re

# Install NLTK resources if not already downloaded
nltk.download('punkt')
nltk.download('stopwords')

# Load dataset with correct encoding
df = pd.read_csv(r"C:\Users\spoorthi\Downloads\DT-10-FINANCIAL-NEWS_main\mydata.csv", encoding='latin1')

# Ensure all non-string values are handled
df['tweets'] = df['tweets'].fillna('').astype(str)

# Step 1: Cleaning the text
cleaned = []
for text in df['tweets']:
    cleaned_text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation and special characters
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text)  # Replace multiple spaces with a single space
    cleaned.append(cleaned_text.strip())  # Strip leading/trailing spaces

# Step 2: Tokenizing the cleaned text
tokens = [word_tokenize(x) for x in cleaned]

# Step 3: Removing stopwords
stop = set(stopwords.words('english'))
stpktn = [[word for word in sentence if word.lower() not in stop] for sentence in tokens]

# Step 4: Displaying results
print("Cleaned Text:", cleaned[:5])  # Display first 5 cleaned texts
print("Tokens:", tokens[:5])  # Display tokens for the first 5 cleaned texts
print("Tokens without Stopwords:", stpktn[:5])  # Display tokens without stopwords for the first 5 cleaned texts
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\spoorthi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\spoorthi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\spoorthi\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tweets'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11536\1936282310.py in <module>
#      14
#      15 # Ensure all non-string values are handled
# ---> 16 df['tweets'] = df['tweets'].fillna('').astype(str)
#      17
#      18 # Step 1: Cleaning the text
#
# c:\Users\spoorthi\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# c:\Users\spoorthi\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tweets'

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3920\1396537375.py in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
df=pd.read_csv('all-data.csv')
# Out:
# Running cells with 'Python 3.7.0' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/spoorthi/AppData/Local/Programs/Python/Python37/python.exe -m pip install ipykernel -U --user --force-reinstall'
